# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score

pd.set_option("display.max_columns", None)

# %%
data = pd.read_csv("/content/petrol_consumption.csv")

# %%
df = data.copy()

# %%
df.head()
# Out:
#    petroltax  income  pavedhighways  driverlicense  petrol_consumption
# 0        9.0    3571           1976          0.525                 541
# 1        9.0    4092           1250          0.572                 524
# 2        9.0    3865           1586          0.580                 561
# 3        7.5    4870           2351          0.529                 414
# 4        8.0    4399            431          0.544                 410

# %% [markdown]
# # independent and dependent feature

# %%
x = df.drop("petrol_consumption",axis = 1)
y = df["petrol_consumption"]

# %% [markdown]
# # train test split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20,random_state=42)

# %% [markdown]
# # Decision tree regressor

# %%
Decision_tree = DecisionTreeRegressor()

# %%
Decision_tree.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
plt.figure(figsize=(25,10))
tree.plot_tree(Decision_tree,filled=True,rounded=True,fontsize=10)
plt.show()

# %%
pred = Decision_tree.predict(x_test)

# %%
r_score = r2_score(y_test,pred)
r_score
# Out:
# 0.2840181861964155

# %% [markdown]
# # the r2 score gives an information about it captures some of the features but we have improve the model
#
# # we can improve the model performance by performing prepruning and postpruning.
